# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
#filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

#CE - the default filter_query provided above was missing parenthesis. I added below.
filter_query = 'section_name:("Movies") AND type_of_material:("Review") AND headline:("love")'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
# CE - ignore (pasted a component of the URL from the nyt website) /articlesearch.json?q={query}&fq={filter}
# CE - ignore (pasted a component of the URL from the nyt website) &api-key=

nyt_api = url + "fq=" + filter_query + "&fl=" + field_list + "&" + sort + "&" + begin_date + "&" + end_date +"&api-key="+ nyt_api_key
# CE- tested below the built URL excluding the field list.
# nyt_api = url + "fq=" + filter_query + "&" + sort + "&" + begin_date + "&" + end_date +"&api-key="+ nyt_api_key

nyt = requests.get(nyt_api).json()

#CE - tested the url by looking at it via .dumps below.
print(json.dumps(nyt, indent=10))
# Out:
# {
#           "status": "OK",
#           "copyright": "Copyright (c) 2024 The New York Times Company. All Rights Reserved.",
#           "response": {
#                     "docs": [
#                               {
#                                         "web_url": "https://www.nytimes.com/2023/06/20/movies/sublime-review.html",
#                                         "snippet": "A teenager dreams of pop songs, and his best friend, in Mariano Biasin\u2019s tender gay coming-of-age drama.",
#                                         "source": "The New York Times",
#                                         "headline": {
#                                                   "main": "\u2018Sublime\u2019 Review: Two Boys, One in Love",
#                                                   "kicker": null,
#                                                   "content_kicker": null,
#                                                   "print_headline": "Sublime",
#                                                   "name": null,
#                                                   "seo": null,
#                                                   "sub": null
#                                         },
#                                         "keywords": [
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "Movies",
#                                                             "rank": 1,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "creative_works",
#                                                             "value": "Sublime (Movie)",
#                                                             "rank": 2,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Biasin, Mariano",
#                                                             "rank": 3,
#                                                             "major": "N"
#                                                   }
#                                         ],
#                                         "pub_date": "2023-06-20T17:48:07+0000",
#                                         "byline": {
#                                                   "original": "By Erik Piepenburg",
#                                                   "person": [
#                                                             {
#                                                                       "firstname": "Erik",
#                                                                       "middlename": null,
#                                                                       "lastname": "Piepenburg",
#                                                                       "qualifier": null,
#                                                                       "title": null,
#                                                                       "role": "reported",
#                                                                       "organization": "",
#                                                                       "rank": 1
#                                                             }
#                                                   ],
#                                                   "organization": null
#                                         },
#                                         "word_count": 266
#                               },
#                               {
#                                         "web_url": "https://www.nytimes.com/2018/01/18/movies/kangaroo-a-love-hate-story-review.html",
#                                         "snippet": "The documentary looks at the mass killings of kangaroos for pet-food companies, leather processors and ranchers in Australia.",
#                                         "source": "The New York Times",
#                                         "headline": {
#                                                   "main": "Review: \u2018Kangaroo: A Love-Hate Story\u2019 Exposes a Wildlife Massacre",
#                                                   "kicker": null,
#                                                   "content_kicker": null,
#                                                   "print_headline": "Kangaroo: A Love-Hate Story",
#                                                   "name": null,
#                                                   "seo": null,
#                                                   "sub": null
#                                         },
#                                         "keywords": [
#                                                   {
#                                                             "name": "creative_works",
#                                                             "value": "Kangaroo: A Love-Hate Story (Movie)",
#                                                             "rank": 1,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "Kangaroos",
#                                                             "rank": 2,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "Animal Abuse, Rights and Welfare",
#                                                             "rank": 3,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "McIntyre Clere, Kate",
#                                                             "rank": 4,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "McIntyre, Mick",
#                                                             "rank": 5,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "Documentary Films and Programs",
#                                                             "rank": 6,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "glocations",
#                                                             "value": "Australia",
#                                                             "rank": 7,
#                                                             "major": "N"
#                                                   }
#                                         ],
#                                         "pub_date": "2018-01-18T12:00:23+0000",
#                                         "byline": {
#                                                   "original": "By Ken Jaworowski",
#                                                   "person": [
#                                                             {
#                                                                       "firstname": "Ken",
#                                                                       "middlename": null,
#                                                                       "lastname": "Jaworowski",
#                                                                       "qualifier": null,
#                                                                       "title": null,
#                                                                       "role": "reported",
#                                                                       "organization": "",
#                                                                       "rank": 1
#                                                             }
#                                                   ],
#                                                   "organization": null
#                                         },
#                                         "word_count": 263
#                               },
#                               {
#                                         "web_url": "https://www.nytimes.com/1991/10/11/movies/short-order-cookery-and-dreams-of-love.html",
#                                         "snippet": "Short-order cookery, dreams of love. Warm and bustling.",
#                                         "source": "The New York Times",
#                                         "headline": {
#                                                   "main": "Short-Order Cookery And Dreams of Love",
#                                                   "kicker": null,
#                                                   "content_kicker": null,
#                                                   "print_headline": "Short-Order Cookery And Dreams of Love",
#                                                   "name": null,
#                                                   "seo": null,
#                                                   "sub": null
#                                         },
#                                         "keywords": [
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "MOTION PICTURES",
#                                                             "rank": 1,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "REVIEW",
#                                                             "rank": 2,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "creative_works",
#                                                             "value": "Frankie and Johnny (Movie)",
#                                                             "rank": 3,
#                                                             "major": "N"
#                                                   }
#                                         ],
#                                         "pub_date": "1991-10-11T05:00:00+0000",
#                                         "byline": {
#                                                   "original": "By Janet Maslin",
#                                                   "person": [
#                                                             {
#                                                                       "firstname": "Janet",
#                                                                       "middlename": null,
#                                                                       "lastname": "Maslin",
#                                                                       "qualifier": null,
#                                                                       "title": null,
#                                                                       "role": "reported",
#                                                                       "organization": "",
#                                                                       "rank": 1
#                                                             }
#                                                   ],
#                                                   "organization": null
#                                         },
#                                         "word_count": 1117
#                               },
#                               {
#                                         "web_url": "https://www.nytimes.com/1989/07/12/movies/review-film-it-s-harry-loves-sally-in-a-romance-of-new-yorkers-and-neuroses.html",
#                                         "snippet": "Rob Reiner\u2019s take on romantically bruised New Yorkers. Ryan\u2019s fake orgasm is still funny.",
#                                         "source": "The New York Times",
#                                         "headline": {
#                                                   "main": "Review/Film; It's Harry  [ Loves ]  Sally in a Romance Of New Yorkers and Neuroses",
#                                                   "kicker": null,
#                                                   "content_kicker": null,
#                                                   "print_headline": "Review/Film; It's Harry  [ Loves ]  Sally in a Romance Of New Yorkers and Neuroses",
#                                                   "name": null,
#                                                   "seo": null,
#                                                   "sub": null
#                                         },
#                                         "keywords": [
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "Reviews",
#                                                             "rank": 1,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "MOTION PICTURES",
#                                                             "rank": 2,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "creative_works",
#                                                             "value": "WHEN HARRY MET SALLY...(MOVIE)",
#                                                             "rank": 3,
#                                                             "major": "N"
#                                                   }
#                                         ],
#                                         "pub_date": "1989-07-12T05:00:00+0000",
#                                         "byline": {
#                                                   "original": "By Caryn James",
#                                                   "person": [
#                                                             {
#                                                                       "firstname": "Caryn",
#                                                                       "middlename": null,
#                                                                       "lastname": "James",
#                                                                       "qualifier": null,
#                                                                       "title": null,
#                                                                       "role": "reported",
#                                                                       "organization": "",
#                                                                       "rank": 1
#                                                             }
#                                                   ],
#                                                   "organization": null
#                                         },
#                                         "word_count": 942
#                               },
#                               {
#                                         "web_url": "https://www.nytimes.com/2013/09/20/movies/jewtopia-a-comedy-directed-by-bryan-fogel.html",
#                                         "snippet": "In \u201cJewtopia,\u201d a young man asks a childhood friend to help him \u201cact Jewish\u201d so he can romance the girl of his dreams.",
#                                         "source": "The New York Times",
#                                         "headline": {
#                                                   "main": "Love\u2019s Eternal Masquerade",
#                                                   "kicker": "Movie Review",
#                                                   "content_kicker": null,
#                                                   "print_headline": "Jewtopia",
#                                                   "name": null,
#                                                   "seo": null,
#                                                   "sub": null
#                                         },
#                                         "keywords": [
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "Movies",
#                                                             "rank": 1,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Sergei, Ivan",
#                                                             "rank": 2,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "creative_works",
#                                                             "value": "Jewtopia (Movie)",
#                                                             "rank": 3,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Fogel, Bryan",
#                                                             "rank": 4,
#                                                             "major": "N"
#                                                   }
#                                         ],
#                                         "pub_date": "2013-09-19T23:33:15+0000",
#                                         "byline": {
#                                                   "original": "By David DeWitt",
#                                                   "person": [
#                                                             {
#                                                                       "firstname": "David",
#                                                                       "middlename": null,
#                                                                       "lastname": "DeWitt",
#                                                                       "qualifier": null,
#                                                                       "title": null,
#                                                                       "role": "reported",
#                                                                       "organization": "",
#                                                                       "rank": 1
#                                                             }
#                                                   ],
#                                                   "organization": null
#                                         },
#                                         "word_count": 272
#                               },
#                               {
#                                         "web_url": "https://www.nytimes.com/2019/05/21/movies/the-tomorrow-man-review.html",
#                                         "snippet": "Blythe Danner and John Lithgow strain to elevate this twee late-life romance.",
#                                         "source": "The New York Times",
#                                         "headline": {
#                                                   "main": "\u2018The Tomorrow Man\u2019 Review: Love Among the Neuroses",
#                                                   "kicker": null,
#                                                   "content_kicker": null,
#                                                   "print_headline": "They Whirl, They Twirl, They Tango",
#                                                   "name": null,
#                                                   "seo": null,
#                                                   "sub": null
#                                         },
#                                         "keywords": [
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "Movies",
#                                                             "rank": 1,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "creative_works",
#                                                             "value": "The Tomorrow Man (Movie)",
#                                                             "rank": 2,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Danner, Blythe",
#                                                             "rank": 3,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Lithgow, John",
#                                                             "rank": 4,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Jones, Noble",
#                                                             "rank": 5,
#                                                             "major": "N"
#                                                   }
#                                         ],
#                                         "pub_date": "2019-05-21T11:00:01+0000",
#                                         "byline": {
#                                                   "original": "By Jeannette Catsoulis",
#                                                   "person": [
#                                                             {
#                                                                       "firstname": "Jeannette",
#                                                                       "middlename": null,
#                                                                       "lastname": "Catsoulis",
#                                                                       "qualifier": null,
#                                                                       "title": null,
#                                                                       "role": "reported",
#                                                                       "organization": "",
#                                                                       "rank": 1
#                                                             }
#                                                   ],
#                                                   "organization": null
#                                         },
#                                         "word_count": 280
#                               },
#                               {
#                                         "web_url": "https://www.nytimes.com/1996/01/12/movies/film-review-equal-opportunity-in-games-of-love.html",
#                                         "snippet": "Housewife pretends to fall for lesbian. Risque comedy.",
#                                         "source": "The New York Times",
#                                         "headline": {
#                                                   "main": "FILM REVIEW;Equal Opportunity in Games of Love",
#                                                   "kicker": "FILM REVIEW",
#                                                   "content_kicker": null,
#                                                   "print_headline": "FILM REVIEW;Equal Opportunity in Games of Love",
#                                                   "name": null,
#                                                   "seo": null,
#                                                   "sub": null
#                                         },
#                                         "keywords": [
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "MOTION PICTURES",
#                                                             "rank": 1,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "Reviews",
#                                                             "rank": 2,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "creative_works",
#                                                             "value": "French Twist (Movie)",
#                                                             "rank": 3,
#                                                             "major": "N"
#                                                   }
#                                         ],
#                                         "pub_date": "1996-01-12T05:00:00+0000",
#                                         "byline": {
#                                                   "original": "By Janet Maslin",
#                                                   "person": [
#                                                             {
#                                                                       "firstname": "Janet",
#                                                                       "middlename": null,
#                                                                       "lastname": "Maslin",
#                                                                       "qualifier": null,
#                                                                       "title": null,
#                                                                       "role": "reported",
#                                                                       "organization": "",
#                                                                       "rank": 1
#                                                             }
#                                                   ],
#                                                   "organization": null
#                                         },
#                                         "word_count": 943
#                               },
#                               {
#                                         "web_url": "https://www.nytimes.com/2019/11/05/movies/marriage-story-review.html",
#                                         "snippet": "Adam Driver and Scarlett Johansson self-consciously uncouple in Noah Baumbach\u2019s tender, stinging tale of divorce.",
#                                         "source": "The New York Times",
#                                         "headline": {
#                                                   "main": "\u2018Marriage Story\u2019 Review: Dance Me to the End of Love",
#                                                   "kicker": "critic\u2019s pick",
#                                                   "content_kicker": null,
#                                                   "print_headline": "Friendly Split, Shattering Break",
#                                                   "name": null,
#                                                   "seo": null,
#                                                   "sub": null
#                                         },
#                                         "keywords": [
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "Movies",
#                                                             "rank": 1,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Baumbach, Noah",
#                                                             "rank": 2,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "creative_works",
#                                                             "value": "Marriage Story (Movie)",
#                                                             "rank": 3,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Driver, Adam",
#                                                             "rank": 4,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Johansson, Scarlett",
#                                                             "rank": 5,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "ALDA, ALAN",
#                                                             "rank": 6,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Dern, Laura",
#                                                             "rank": 7,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Liotta, Ray",
#                                                             "rank": 8,
#                                                             "major": "N"
#                                                   }
#                                         ],
#                                         "pub_date": "2019-11-05T19:01:02+0000",
#                                         "byline": {
#                                                   "original": "By A.O. Scott",
#                                                   "person": [
#                                                             {
#                                                                       "firstname": "A.",
#                                                                       "middlename": "O.",
#                                                                       "lastname": "Scott",
#                                                                       "qualifier": null,
#                                                                       "title": null,
#                                                                       "role": "reported",
#                                                                       "organization": "",
#                                                                       "rank": 1
#                                                             }
#                                                   ],
#                                                   "organization": null
#                                         },
#                                         "word_count": 1244
#                               },
#                               {
#                                         "web_url": "https://www.nytimes.com/2022/11/17/movies/bones-and-all-review.html",
#                                         "snippet": "Luca Guadagnino\u2019s latest stars Timoth\u00e9e Chalamet and Taylor Russell as young cannibals on the run.",
#                                         "source": "The New York Times",
#                                         "headline": {
#                                                   "main": "\u2018Bones and All\u2019 Review: You Eat What You Are",
#                                                   "kicker": null,
#                                                   "content_kicker": null,
#                                                   "print_headline": "It\u2019s Eat, Prey, Love on a Journey of Self-Discovery",
#                                                   "name": null,
#                                                   "seo": null,
#                                                   "sub": null
#                                         },
#                                         "keywords": [
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "Movies",
#                                                             "rank": 1,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "creative_works",
#                                                             "value": "Bones and All (Movie)",
#                                                             "rank": 2,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Guadagnino, Luca",
#                                                             "rank": 3,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Chalamet, Timothee (1995- )",
#                                                             "rank": 4,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Russell, Taylor (1994- )",
#                                                             "rank": 5,
#                                                             "major": "N"
#                                                   }
#                                         ],
#                                         "pub_date": "2022-11-17T12:00:06+0000",
#                                         "byline": {
#                                                   "original": "By A.O. Scott",
#                                                   "person": [
#                                                             {
#                                                                       "firstname": "A.",
#                                                                       "middlename": "O.",
#                                                                       "lastname": "Scott",
#                                                                       "qualifier": null,
#                                                                       "title": null,
#                                                                       "role": "reported",
#                                                                       "organization": "",
#                                                                       "rank": 1
#                                                             }
#                                                   ],
#                                                   "organization": null
#                                         },
#                                         "word_count": 710
#                               },
#                               {
#                                         "web_url": "https://www.nytimes.com/2019/08/08/movies/love-anthosa-review.html",
#                                         "snippet": "Anton Yelchin, who played Chekov in the J.J. Abrams-produced \u201cStar Trek\u201d films, assembled an eclectic filmography before his death at 27 in 2016.",
#                                         "source": "The New York Times",
#                                         "headline": {
#                                                   "main": "\u2018Love, Antosha\u2019 Review: A Heartbreaking Look at an Actor\u2019s Too-Short Life",
#                                                   "kicker": "Critic\u2019s Pick",
#                                                   "content_kicker": null,
#                                                   "print_headline": "Love, Antosha",
#                                                   "name": null,
#                                                   "seo": null,
#                                                   "sub": null
#                                         },
#                                         "keywords": [
#                                                   {
#                                                             "name": "subject",
#                                                             "value": "Documentary Films and Programs",
#                                                             "rank": 1,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "creative_works",
#                                                             "value": "Love, Antosha (Movie)",
#                                                             "rank": 2,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Price, Garret",
#                                                             "rank": 3,
#                                                             "major": "N"
#                                                   },
#                                                   {
#                                                             "name": "persons",
#                                                             "value": "Yelchin, Anton",
#                                                             "rank": 4,
#                                                             "major": "N"
#                                                   }
#                                         ],
#                                         "pub_date": "2019-08-08T09:00:10+0000",
#                                         "byline": {
#                                                   "original": "By Glenn Kenny",
#                                                   "person": [
#                                                             {
#                                                                       "firstname": "Glenn",
#                                                                       "middlename": null,
#                                                                       "lastname": "Kenny",
#                                                                       "qualifier": null,
#                                                                       "title": null,
#                                                                       "role": "reported",
#                                                                       "organization": "",
#                                                                       "rank": 1
#                                                             }
#                                                   ],
#                                                   "organization": null
#                                         },
#                                         "word_count": 319
#                               }
#                     ],
#                     "meta": {
#                               "hits": 980,
#                               "offset": 0,
#                               "time": 18
#                     }
#           }
# }

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(0, 20):

    # create query with a page number
    # API results show 10 articles at a time
    nyt_pages_url = nyt_api + "&page=" + str(page)

    
    # Make a "GET" request and retrieve the JSON
    nyt_pages = requests.get(nyt_pages_url).json()

    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    
    try:

        # loop through the reviews["response"]["docs"] and append each review to the list

        reviews_list.append(nyt_pages["response"]["docs"])
        
        # Print the page that was just retrieved
        print("Page "+str(page)+" retrieved and appended.")

        # Print the page number that had no results then break from the loop
        
    except Exception:
        print("Page "+ str(page) + " had no results.")
        pass
# Out:
# Page 0 retrieved and appended.
# Page 1 retrieved and appended.
# Page 2 retrieved and appended.
# Page 3 retrieved and appended.
# Page 4 had no results.
# Page 5 retrieved and appended.
# Page 6 retrieved and appended.
# Page 7 retrieved and appended.
# Page 8 retrieved and appended.
# Page 9 retrieved and appended.
# Page 10 retrieved and appended.
# Page 11 retrieved and appended.
# Page 12 retrieved and appended.
# Page 13 retrieved and appended.
# Page 14 retrieved and appended.
# Page 15 retrieved and appended.
# Page 16 retrieved and appended.
# Page 17 retrieved and appended.
# Page 18 retrieved and appended.
# Page 19 retrieved and appended.

# %%
# CE Note: my results above created lists nested within a list. 
# CE Note: I created a for loop / line comprehension below to extract the nested lists from the list
#flat_list =[]
# for l in reviews_list:
#     for x in list:
#         flat_list.append(x)
# print(flat_list)
    
flat_list = [x for l in reviews_list for x in l]  
print(flat_list)
# Out:
# [{'web_url': 'https://www.nytimes.com/2023/06/20/movies/sublime-review.html', 'snippet': 'A teenager dreams of pop songs, and his best friend, in Mariano Biasin’s tender gay coming-of-age drama.', 'source': 'The New York Times', 'headline': {'main': '‘Sublime’ Review: Two Boys, One in Love', 'kicker': None, 'content_kicker': None, 'print_headline': 'Sublime', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'Sublime (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Biasin, Mariano', 'rank': 3, 'major': 'N'}], 'pub_date': '2023-06-20T17:48:07+0000', 'byline': {'original': 'By Erik Piepenburg', 'person': [{'firstname': 'Erik', 'middlename': None, 'lastname': 'Piepenburg', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 266}, {'web_url': 'https://www.nytimes.com/2018/01/18/movies/kangaroo-a-love-hate-story-review.html', 'snippet': 'The documentary looks at the mass killings of kangaroos for pet-food companies, leather processors and ranchers in Australia.', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacre', 'kicker': None, 'content_kicker': None, 'print_headline': 'Kangaroo: A Love-Hate Story', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'creative_works', 'value': 'Kangaroo: A Love-Hate Story (Movie)', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Kangaroos', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Animal Abuse, Rights and Welfare', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'McIntyre Clere, Kate', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'McIntyre, Mick', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 6, 'major': 'N'}, {'name': 'glocations', 'value': 'Australia', 'rank': 7, 'major': 'N'}], 'pub_date': '2018-01-18T12:00:23+0000', 'byline': {'original': 'By Ken Jaworowski', 'person': [{'firstname': 'Ken', 'middlename': None, 'lastname': 'Jaworowski', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 263}, {'web_url': 'https://www.nytimes.com/1991/10/11/movies/short-order-cookery-and-dreams-of-love.html', 'snippet': 'Short-order cookery, dreams of love. Warm and bustling.', 'source': 'The New York Times', 'headline': {'main': 'Short-Order Cookery And Dreams of Love', 'kicker': None, 'content_kicker': None, 'print_headline': 'Short-Order Cookery And Dreams of Love', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'MOTION PICTURES', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'REVIEW', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'Frankie and Johnny (Movie)', 'rank': 3, 'major': 'N'}], 'pub_date': '1991-10-11T05:00:00+0000', 'byline': {'original': 'By Janet Maslin', 'person': [{'firstname': 'Janet', 'middlename': None, 'lastname': 'Maslin', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1117}, {'web_url': 'https://www.nytimes.com/1989/07/12/movies/review-film-it-s-harry-loves-sally-in-a-romance-of-new-yorkers-and-neuroses.html', 'snippet': 'Rob Reiner’s take on romantically bruised New Yorkers. Ryan’s fake orgasm is still funny.', 'source': 'The New York Times', 'headline': {'main': "Review/Film; It's Harry  [ Loves ]  Sally in a Romance Of New Yorkers and Neuroses", 'kicker': None, 'content_kicker': None, 'print_headline': "Review/Film; It's Harry  [ Loves ]  Sally in a Romance Of New Yorkers and Neuroses", 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Reviews', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'MOTION PICTURES', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'WHEN H ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
reviews_flat = flat_list.copy()
# reviews_flat_5 = reviews_flat[:5]
print(json.dumps(reviews_flat[:5],indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/06/20/movies/sublime-review.html",
#         "snippet": "A teenager dreams of pop songs, and his best friend, in Mariano Biasin\u2019s tender gay coming-of-age drama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Sublime\u2019 Review: Two Boys, One in Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Sublime",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Sublime (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Biasin, Mariano",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-06-20T17:48:07+0000",
#         "byline": {
#             "original": "By Erik Piepenburg",
#             "person": [
#                 {
#                     "firstname": "Erik",
#                     "middlename": null,
#                     "lastname": "Piepenburg",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 266
#     },
#     {
#         "web_url": "https://www.nytimes.com/2018/01/18/movies/kangaroo-a-love-hate-story-review.html",
#         "snippet": "The documentary looks at the mass killings of kangaroos for pet-food companies, leather processors and ranchers in Australia.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Kangaroo: A Love-Hate Story\u2019 Exposes a Wildlife Massacre",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Kangaroo: A Love-Hate Story",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "creative_works",
#                 "value": "Kangaroo: A Love-Hate Story (Movie)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Kangaroos",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Animal Abuse, Rights and Welfare",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "McIntyre Clere, Kate",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "McIntyre, Mick",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Australia",
#                 "rank": 7,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2018-01-18T12:00:23+0000",
#         "byline": {
#             "original": "By Ken Jaworowski",
#             "person": [
#                 {
#                     "firstname": "Ken",
#                     "middlename": null,
#                     "lastname": "Jaworowski",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 263
#     },
#     {
#         "web_url": "https://www.nytimes.com/1991/10/11/movies/short-order-cookery-and-dreams-of-love.html",
#         "snippet": "Short-order cookery, dreams of love. Warm and bustling.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Short-Order Cookery And Dreams of Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Short-Order Cookery And Dreams of Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "MOTION PICTURES",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "REVIEW",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Frankie and Johnny (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "1991-10-11T05:00:00+0000",
#         "byline": {
#             "original": "By Janet Maslin",
#             "person": [
#                 {
#                     "firstname": "Janet",
#                     "middlename": null,
#                     "lastname": "Maslin",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1117
#     },
#     {
#         "web_url": "https://www.nytimes.com/1989/07/12/movies/review-film-it-s-harry-loves-sally-in-a-romance-of-new-yorkers-and-neuroses.html",
#         "snippet": "Rob Reiner\u2019s take on romantically bruised New Yorkers. Ryan\u2019s fake orgasm is still funny.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review/Film; It's Harry  [ Loves ]  Sally in a Romance Of New Yorkers and Neuroses",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Review/Film; It's Harry  [ Loves ]  Sally in a Romance Of New Yorkers and Neuroses",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Reviews",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "MOTION PICTURES",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "WHEN HARRY MET SALLY...(MOVIE)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "1989-07-12T05:00:00+0000",
#         "byline": {
#             "original": "By Caryn James",
#             "person": [
#                 {
#                     "firstname": "Caryn",
#                     "middlename": null,
#                     "lastname": "James",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 942
#     },
#     {
#         "web_url": "https://www.nytimes.com/2013/09/20/movies/jewtopia-a-comedy-directed-by-bryan-fogel.html",
#         "snippet": "In \u201cJewtopia,\u201d a young man asks a childhood friend to help him \u201cact Jewish\u201d so he can romance the girl of his dreams.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Love\u2019s Eternal Masquerade",
#             "kicker": "Movie Review",
#             "content_kicker": null,
#             "print_headline": "Jewtopia",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Sergei, Ivan",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Jewtopia (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Fogel, Bryan",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2013-09-19T23:33:15+0000",
#         "byline": {
#             "original": "By David DeWitt",
#             "person": [
#                 {
#                     "firstname": "David",
#                     "middlename": null,
#                     "lastname": "DeWitt",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 272
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_flat)
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/06/20/movies/subl...
# 1    https://www.nytimes.com/2018/01/18/movies/kang...
# 2    https://www.nytimes.com/1991/10/11/movies/shor...
# 3    https://www.nytimes.com/1989/07/12/movies/revi...
# 4    https://www.nytimes.com/2013/09/20/movies/jewt...
# ..                                                 ...
# 185  https://www.nytimes.com/1999/10/29/movies/coun...
# 186  https://www.nytimes.com/2017/11/09/movies/revi...
# 187  https://www.nytimes.com/1997/08/29/movies/thef...
# 188  https://www.nytimes.com/1994/11/04/movies/film...
# 189  https://www.nytimes.com/2016/05/20/movies/-alm...
#
#                                                snippet              source  \
# 0    A teenager dreams of pop songs, and his best f...  The New York Times
# 1    The documentary looks at the mass killings of ...  The New York Times
# 2    Short-order cookery, dreams of love. Warm and ...  The New York Times
# 3    Rob Reiner’s take on romantically bruised New ...  The New York Times
# 4    In “Jewtopia,” a young man asks a childhood fr...  The New York Times
# ..                                                 ...                 ...
# 185  Ben Ratliff reviews country music performance ...  The New York Times
# 186  In Joachim Trier’s sly psychological thriller ...  The New York Times
# 187  Irish Gypsy leader betrayed. Splendid performa...  The New York Times
# 188  Vietnam veteran and children in 1970 Mississip...  The New York Times
# 189  This documentary by Steve Hoover examines Genn...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'creative_works', 'value': 'Kangaroo...
# 2    [{'name': 'subject', 'value': 'MOTION PICTURES...
# 3    [{'name': 'subject', 'value': 'Reviews', 'rank...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 185  [{'name': 'persons', 'value': 'Black, Clint', ...
# 186  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 187  [{'name': 'persons', 'value': 'Harris, Richard...
# 188  [{'name': 'persons', 'value': 'Avnet, Jon', 'r...
# 189  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                      pub_date  word_count  \
# 0    2023-06-20T17:48:07+0000         266
# 1    2018-01-18T12:00:23+0000         263
# 2    1991-10-11T05:00:00+0000        1117
# 3    1989-07-12T05:00:00+0000         942
# 4    2013-09-19T23:33:15+0000         272
# ..                        ...         ...
# 185  1999-10-29T05:00:00+0000         352
# 186  2017-11-09T20:08:31+0000         757
# 187  1997-08-29T05:00:00+0000         602
# 188  1994-11-04T05:00:00+0000         710
# 189  2016-05-19T21:34:29+0000         253
#
#                                          headline.main headline.kicker  \
# 0              ‘Sublime’ Review: Two Boys, One in Love            None
# 1    Review: ‘Kangaroo: A Love-Hate Story’ Exposes ...            None
# 2               Short-Order Cookery And Dreams of Love            None
# 3    Review/Film; It's Harry  [ Loves ]  Sally in a...            None
# 4                            Love’s Eternal Masquerade    Movie Review
# ..                                                 ...             ...
# 185  Where Hearts Don't Cheat, And Love Is the Current   COUNTRY MUSIC
# 186  Review: In ‘Thelma,’ a Woman in Love Can Burn ...            None
# 187                  Theft, Adultery and Good Old Love     FILM REVIEW
# 188        Family Values and Love In Vietnam Aftermath     FILM REVIEW
# 189  Review: ‘Almost Holy’ Demonstrates a Pastor’s ...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 185                    None
# 186                    None
# 187                    None
# 188                    None
# 189                    None
#
#                                headline.print_headline headline.name  \
# 0                                              Sublime          None
# 1                          Kangaroo: A Love-Hate Story          None
# 2               Short-Order Cookery And Dreams of Love          None
# 3    Review/Film; It's Harry  [ Loves ]  Sally in a...          None
# 4                                             Jewtopia          None
# ..                                                 ...           ...
# 185  COUNTRY MUSIC; Where Hearts Don't Cheat, And L...          None
# 186            A Woman in Love Can Burn Down the World          None
# 187                  Theft, Adultery and Good Old Love          None
# 188  FILM REVIEW; Family Values and Love In Vietnam...          None
# 189  Review: ‘Almost Holy’ Demonstrates a Pastor’s ...          None
#
#     headline.seo headline.sub     byline.original  \
# 0           None         None  By Erik Piepenburg
# 1           None         None   By Ken Jaworowski
# 2           None         None     By Janet Maslin
# 3           None         None      By Caryn James
# 4           None         None     By David DeWitt
# ..           ...          ...                 ...
# 185         None         None      By Ben Ratliff
# 186         None         None   By Manohla Dargis
# 187         None         None   By Stephen Holden
# 188         None         None     By Janet Maslin
# 189         None         None   By Ben Kenigsberg
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Erik', 'middlename': None, 'la...                None
# 1    [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 2    [{'firstname': 'Janet', 'middlename': None, 'l...                None
# 3    [{'firstname': 'Caryn', 'middlename': None, 'l...                None
# 4    [{'firstname': 'David', 'middlename': None, 'l...                None
# ..                                                 ...                 ...
# 185  [{'firstname': 'Ben', 'middlename': None, 'las...                None
# 186  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 187  [{'firstname': 'Stephen', 'middlename': None, ...                None
# 188  [{'firstname': 'Janet', 'middlename': None, 'l...                None
# 189  [{'firstname': 'Ben', 'middlename': None, 'las...                None
#
# [190 rows x 16 columns]

# %% [markdown]
# CE Note: Pasted part of the Challenge documentation:
# Extract the movie title from the "headline.main" column and save it to a new column "title". To do this, you will use the Pandas apply() method and the following lambda function:
#
# This code takes the string in the cell and extracts the characters between the unicode quotation marks, as long as a space and the word "Review" follows the closing quotation mark.
#
# lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")]
# These titles will be used in the query for The Movie Database.

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# # End string should include " Review" to avoid cutting title early

#CE Note: Pasted from challenge instructions:
#st[st.find("\u2018")+1:st.find("\u2019 Review")]

#CE Note: My code wasn't working. Chatgpt provided guidance that advised that I shouldn't have the apply within a list.
reviews_df["title"] = reviews_df["headline.main"].apply(lambda x: x[x.find("\u2018") + 1 : x.find("\u2019 Review")])

 
#reviews_df["title"] = reviews_df["headline.main"].apply(lambda x: x[x.find("\u2018") + 1 : x.find("\u2019 Review")] if ("\u2018" in x and "\u2019 Review" in x) else x)


reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/06/20/movies/subl...
# 1    https://www.nytimes.com/2018/01/18/movies/kang...
# 2    https://www.nytimes.com/1991/10/11/movies/shor...
# 3    https://www.nytimes.com/1989/07/12/movies/revi...
# 4    https://www.nytimes.com/2013/09/20/movies/jewt...
# ..                                                 ...
# 185  https://www.nytimes.com/1999/10/29/movies/coun...
# 186  https://www.nytimes.com/2017/11/09/movies/revi...
# 187  https://www.nytimes.com/1997/08/29/movies/thef...
# 188  https://www.nytimes.com/1994/11/04/movies/film...
# 189  https://www.nytimes.com/2016/05/20/movies/-alm...
#
#                                                snippet              source  \
# 0    A teenager dreams of pop songs, and his best f...  The New York Times
# 1    The documentary looks at the mass killings of ...  The New York Times
# 2    Short-order cookery, dreams of love. Warm and ...  The New York Times
# 3    Rob Reiner’s take on romantically bruised New ...  The New York Times
# 4    In “Jewtopia,” a young man asks a childhood fr...  The New York Times
# ..                                                 ...                 ...
# 185  Ben Ratliff reviews country music performance ...  The New York Times
# 186  In Joachim Trier’s sly psychological thriller ...  The New York Times
# 187  Irish Gypsy leader betrayed. Splendid performa...  The New York Times
# 188  Vietnam veteran and children in 1970 Mississip...  The New York Times
# 189  This documentary by Steve Hoover examines Genn...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'creative_works', 'value': 'Kangaroo...
# 2    [{'name': 'subject', 'value': 'MOTION PICTURES...
# 3    [{'name': 'subject', 'value': 'Reviews', 'rank...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 185  [{'name': 'persons', 'value': 'Black, Clint', ...
# 186  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 187  [{'name': 'persons', 'value': 'Harris, Richard...
# 188  [{'name': 'persons', 'value': 'Avnet, Jon', 'r...
# 189  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                      pub_date  word_count  \
# 0    2023-06-20T17:48:07+0000         266
# 1    2018-01-18T12:00:23+0000         263
# 2    1991-10-11T05:00:00+0000        1117
# 3    1989-07-12T05:00:00+0000         942
# 4    2013-09-19T23:33:15+0000         272
# ..                        ...         ...
# 185  1999-10-29T05:00:00+0000         352
# 186  2017-11-09T20:08:31+0000         757
# 187  1997-08-29T05:00:00+0000         602
# 188  1994-11-04T05:00:00+0000         710
# 189  2016-05-19T21:34:29+0000         253
#
#                                          headline.main headline.kicker  \
# 0              ‘Sublime’ Review: Two Boys, One in Love            None
# 1    Review: ‘Kangaroo: A Love-Hate Story’ Exposes ...            None
# 2               Short-Order Cookery And Dreams of Love            None
# 3    Review/Film; It's Harry  [ Loves ]  Sally in a...            None
# 4                            Love’s Eternal Masquerade    Movie Review
# ..                                                 ...             ...
# 185  Where Hearts Don't Cheat, And Love Is the Current   COUNTRY MUSIC
# 186  Review: In ‘Thelma,’ a Woman in Love Can Burn ...            None
# 187                  Theft, Adultery and Good Old Love     FILM REVIEW
# 188        Family Values and Love In Vietnam Aftermath     FILM REVIEW
# 189  Review: ‘Almost Holy’ Demonstrates a Pastor’s ...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 185                    None
# 186                    None
# 187                    None
# 188                    None
# 189                    None
#
#                                headline.print_headline headline.name  \
# 0                                              Sublime          None
# 1                          Kangaroo: A Love-Hate Story          None
# 2               Short-Order Cookery And Dreams of Love          None
# 3    Review/Film; It's Harry  [ Loves ]  Sally in a...          None
# 4                                             Jewtopia          None
# ..                                                 ...           ...
# 185  COUNTRY MUSIC; Where Hearts Don't Cheat, And L...          None
# 186            A Woman in Love Can Burn Down the World          None
# 187                  Theft, Adultery and Good Old Love          None
# 188  FILM REVIEW; Family Values and Love In Vietnam...          None
# 189  Review: ‘Almost Holy’ Demonstrates a Pastor’s ...          None
#
#     headline.seo headline.sub     byline.original  \
# 0           None         None  By Erik Piepenburg
# 1           None         None   By Ken Jaworowski
# 2           None         None     By Janet Maslin
# 3           None         None      By Caryn James
# 4           None         None     By David DeWitt
# ..           ...          ...                 ...
# 185         None         None      By Ben Ratliff
# 186         None         None   By Manohla Dargis
# 187         None         None   By Stephen Holden
# 188         None         None     By Janet Maslin
# 189         None         None   By Ben Kenigsberg
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Erik', 'middlename': None, 'la...                None
# 1    [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 2    [{'firstname': 'Janet', 'middlename': None, 'l...                None
# 3    [{'firstname': 'Caryn', 'middlename': None, 'l...                None
# 4    [{'firstname': 'David', 'middlename': None, 'l...                None
# ..                                                 ...                 ...
# 185  [{'firstname': 'Ben', 'middlename': None, 'las...                None
# 186  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 187  [{'firstname': 'Stephen', 'middlename': None, ...                None
# 188  [{'firstname': 'Janet', 'middlename': None, 'l...                None
# 189  [{'firstname': 'Ben', 'middlename': None, 'las...                None
#
#                                                  title
# 0                                              Sublime
# 1    Kangaroo: A Love-Hate Story’ Exposes a Wildlif...
# 2                Short-Order Cookery And Dreams of Lov
# 3    Review/Film; It's Harry  [ Loves ]  Sally in a...
# 4                             Love’s Eternal Masquerad
# ..                                                 ...
# 185   Where Hearts Don't Cheat, And Love Is the Curren
# 186    Thelma,’ a Woman in Love Can Burn Down the Worl
# 187                   Theft, Adultery and Good Old Lov
# 188         Family Values and Love In Vietnam Aftermat
# 189  Almost Holy’ Demonstrates a Pastor’s Tough Lov...
#
# [190 rows x 17 columns]

# %%
#CE NOTE: Ignore this cell, I did not see the function provided in the challenge notes before doing below.

#CE Note: Initially googled and chatgpt-ed to figure out how to extract from a string.
# CE first attempt:
# quotes = r'[\u2018\u2019](.*?)[\u2018\u2019]'
# quotes2 = r"['][\u2018\u2019](.*?)[\u2018\u2019][']"
# reviews_df["title"] = ""
# i = 0

#for line in reviews_df["headline.main"]:
#     if quotes or quotes2 in line:
#         reviews_df.iloc[i,-1] = line.str.extract(quotes)
#         i+= 1
#     else:
#         reviews_df.iloc[i,-1] = line
#         i+= 1

# reviews_df.head()

#CE second attempt:
# for line in reviews_df["headline.main"]:
#     if quotes or quotes2 in line:
#         extract = reviews_df["headline.main"].str.extract(quotes)
#         reviews_df.iloc[i,-1] = extract[i]
#         i+= 1
#     else:
#         reviews_df.iloc[i,-1] = line
#         i+= 1
## quotes = r'\u2018(.*?)\u2019'
## quotes2 = r"\'(.*?) \'" 




# CE third attempt:
# for line in reviews_df["headline.main"]:
#     if quotes in line or quotes2 in line:
#         extract = reviews_df["headline.main"].str.extract(quotes)
#         reviews_df.iloc[i, -1] = extract.iloc[i, 0]
#     else:
#         reviews_df.iloc[i, -1] = line
#     i += 1

# for line in reviews_df["headline.main"]:
#     if quotes in line or quotes2 in line:
#         extract = reviews_df["headline.main"].str.extract(quotes)
#         reviews_df.iloc[i, -1] = extract.iloc[0, 0] if not extract.empty else None
#     else:
#         reviews_df.iloc[i, -1] = line
#     i += 1

# CE note: Further queries on chatgpt and was provided guidance using re.findall as below: 
# import re
# quotes = r'\u2018(.*?)\u2019'
# quotes2 = r"\'(.*?) \' "
# reviews_df["title"] = ""

# for i, line in enumerate(reviews_df["headline.main"]):
#     updated = re.findall(quotes, line) or re.findall(quotes2, line)
#     if updated:
#         reviews_df.iloc[i, -1] = updated[0]
#     else:
#         reviews_df.iloc[i, -1] = line

# reviews_df.head()

# %%
## CE NOTE: for prompt in cell below I've extracted all the info of one of the df keywords column cell to see the full info.
reviews_df["keywords"].iloc[0]
# Out:
# [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'},
#  {'name': 'creative_works',
#   'value': 'Sublime (Movie)',
#   'rank': 2,
#   'major': 'N'},
#  {'name': 'persons', 'value': 'Biasin, Mariano', 'rank': 3, 'major': 'N'}]

# %%
# Extract 'name' and 'value' from items in "keywords" column
#CE note: pasted from the other challenge instructions: Use the supplied extract_keywords function to convert 
#the "keywords" column from a list of dictionaries to strings using the apply() method.


def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords



# Fix the "keywords" column by converting cells from a list to a string


reviews_df["keywords"] = reviews_df["keywords"].apply(lambda x: extract_keywords(x))

#CE Note: created another iloc to confirm the column's data returned as required.
reviews_df["keywords"].iloc[0]
# Out:
# 'subject: Movies;creative_works: Sublime (Movie);persons: Biasin, Mariano;'

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = reviews_df["title"].to_list()
titles
# Out:
# ['Sublime',
#  'Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr',
#  'Short-Order Cookery And Dreams of Lov',
#  "Review/Film; It's Harry  [ Loves ]  Sally in a Romance Of New Yorkers and Neurose",
#  'Love’s Eternal Masquerad',
#  'The Tomorrow Man',
#  'FILM REVIEW;Equal Opportunity in Games of Lov',
#  'Marriage Story',
#  'Bones and All',
#  'Love, Antosha',
#  'You Can Live Forever',
#  'From Tapestried Villa to Sylvan Glade, Aristocratic Women in Lov',
#  "A Love Triangle Like No Other in 'Two Drifters'",
#  'Teenager Dies, Leaving Love, and a Life, Behin',
#  'FILM REVIEW;Of a Circus, Church and Lesbian Lov',
#  'Homage to a Poet Who Loved Polan',
#  'Review/Film;   Love and Pain Among the Gentry in Irelan',
#  'Prem Ratan Dhan Payo,’ a Bollywood Tale of a Prince-and-Plebe Doubl',
#  'Review/Film; Mysticism and Love Inside a Hammer and Sickl',
#  'A Promoter Finds a New Cause: Go',
#  'Now They’ll Love Me, a Twin Sister Scheme',
#  'On the Streets of Lisbon, Love, Romance and Desir',
#  'They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil',
#  "The Trivially Hip: A Music Geek's Warped Love Lif",
#  'A Journal for Jordan',
#  'Sexism and Rothbart As Obstacles to Lov',
#  'Another Version of Star-Crossed Lov',
#  'A United Kingdom’ With Love That Tested Racial Toleranc',
#  'A Father and a Son Tell Their Own Tales of Love and Los',
#  'Who’s Afraid of an Artist Who Loved Flowers',
#  'Proof That Science Can’t Find You Lov',
#  'Serenading Love and Life, 30 Years Afte',
#  'For the Love of Money And the Risks of Making I',
#  'Joseph Loves Sarah and So Does Frank, and Everybody Is Talking About I',
#  'Love in Transitio',
#  'Sophie and the Rising Sun’ Has Forbidden Love in a Foreboding Tim',
#  'Their Love Will Go On In Outer Spac',
#  'A Young Viagra Salesman Sees Lust Turn Into Lov',
#  'Loved One',
#  '50 Years and 600 Women Later, True Lov',
#  "'ELENI' ENSHRINES ON FILM A MOTHER'S LEGACY OF LOV",
#  'Italians in Lov',
#  "Books of The Times; Wastepaper Love Story Amid the Cellar's Secret",
#  'Reviews/Film; Of Butchers and Lov',
#  'Review/Film; Love Is Blind And Memory Is Bluffe',
#  'Love and Unhappiness, in Soft Shades of Gra',
#  'Lost in Paris',
#  'Lost and Love’ (‘Shi Gu’) Stars Andy Lau as a Man Searching for His Lost So',
#  'The Elaborate Fantasies of Love and Longin',
#  'The Love Triangle as One-Man Sho',
#  'Love to Build Them Up, Love to Tear Them Dow',
#  'From This Day Forward’ Attests to Love’s Adaptabilit',
#  'A Whole Lotta Interconnected Love, and a Whole Lotta Movie Star',
#  'How He Fell in Love,’ an Extramarital Bond Unfold',
#  'When Not Making Love, They Dress Fabulousl',
#  'Young Love, Interrupted by a Nuclear Bom',
#  'Young Love, Tragedy And a Poe',
#  'FILM REVIEW;Love Comes Driving Up the Road, and in Middle Age, To',
#  "'Leather Jacket Love Story'; Directed by David DeCoteau; Not rated; 85 minute",
#  'Tough Love for a Tough Gir',
#  'Love the Coopers,’ a Dysfunctional Family Sits Down to Christmas Dinne',
#  'Ma Ma,’ Penélope Cruz as a Cancer Patient Finding Lov',
#  'The Shape of Water’ Is Altogether Wonderfu',
#  'Review/Film Festival; Action, History, Politics And Love Above Al',
#  "For an Actress's Husband, Love Scenes Aren't Sex",
#  "FILM REVIEW;If They Haven't Found Love by 30, They'll Jump. Well, O.K",
#  'Fallen Leaves',
#  'Foe',
#  'Love After Love,’ an Unflinching Look at Extended Grie',
#  'Love & Mercy’ Gets Inside Brian Wilson’s Hea',
#  'Women Who Kill,’ and May Be in Love With On',
#  'He’s in Love, but No Closer to Figuring It Ou',
#  'Stealing Love and Loyalty, Among Some Other Thing',
#  'Review/Television; On the Many Splendors Of Long-Lasting Lov',
#  "FILM: 'EMPTY QUARTER,' VIEW OF LOVE AND AFRIC",
#  'Hard Luck Love Song',
#  'See You Then',
#  'An Obsessive Love of Praye',
#  'Review/Film; Memories Of Madness And Lov',
#  "It's Love That Maketh Thy World Go Roun",
#  "FILM REVIEW;Kieslowski's Drama Of a Voyeur in Lov",
#  'Race, Love and the Black Proprietie',
#  'Mirrors of Love, Unapologetically Your',
#  'Love Conquers All in Occupied Japa',
#  'A Love Triangle Ignited By What Might Have Bee',
#  'Red, White & Royal Blue',
#  'Kalank',
#  'Z for Zachariah,’ an End-of-Days Love Triangl',
#  'Your Name Engraved Herein',
#  'FILM: SAGA OF LOVE AND WAR IN JAPA',
#  'Youth,’ the People’s Dance Troupe, in Love and Wa',
#  'Of Star-Crossed Love, With Cross-Dressed Cas',
#  'FILM REVIEW;Complicated Life Redeemed by Lov',
#  'Review/Film; Love in a New York Isosceles Triangl',
#  "In 'Just My Luck,' Lindsay Lohan Is a Career Girl Hunting Lov",
#  'Love and Sals',
#  'Into the Blur Of Meanings Love Create',
#  'Review/Film; Mismatched Teen-Agers Fall in Love, Of Cours',
#  'Time Bent, Love Tested And Illness Faced Dow',
#  'Tu Me Manques',
#  "FILM: 'LOVE SONGS,' WITH DENEUVE AND LAMBER",
#  'Together',
#  'Review/Film;   Things That Can Happen When People Fall in Lov',
#  "Review/Film;   'White Palace': Love And the Class Struggl",
#  'Chemistry of Alienation and First Lov',
#  'Wanted: A Third Party to Complete Love Triangl',
#  'In the Stars: All Together In Love and Coincidenc',
#  'Before, Now & Then',
#  'Unlucky in Her Loves, Lucky in Her Song',
#  'Alcarràs',
#  'Queen & Slim',
#  'A Walk in the Woods Explores the Layers of Lov',
#  'Starting Off With Sex, Ending Up With Lov',
#  'Falling in Love With the Object of Disgus',
#  'Love Songs And Other Delights From Brazi',
#  'Parables That Blend Love and Philosoph',
#  'Falling Inn Love',
#  'Make a Date With Lov',
#  'The Bonds of Family Love In a Fight Against Tim',
#  "Keanu Reeves and Sandra Bullock Are Reunited in 'The Lake House",
#  'Tamasha,’ Finding a Path to Love, Show Business and Adulatio',
#  'The Sun Is Also a Star',
#  'Cathedrals of Culture,’ Buildings to Lov',
#  'Cursed With a Face Only a Sow Could Lov',
#  'Love, Guilt, Immolation and Gypsie',
#  'The Creator',
#  'When Love of Religion Leads to Hatred of Other',
#  'Love, Honor and Duty In Codified Old Castill',
#  "'For da Love of Money",
#  'When Love Registers at a Motel, Send Win',
#  'First Handcuffs Lock Them Together, Then Lov',
#  "FILM VIEW;The Joy of Renouncing Love for Life's Detail",
#  'Book of Love',
#  'My Psychedelic Love Story',
#  'How to Talk to Girls at Parties',
#  "Solar Eclipse of the Heart: Love in a Suburb of the 50'",
#  'Oh, for the Blood of Pete! (Slashing Away at Love',
#  "SCREEN: 'SPLASH,' A MERMAID'S LOV",
#  'Flowers’ Leaves Three Women Pining for the Same Lost Lov',
#  'All the Bright Places',
#  'Touched With Fire,’ a Love Story Between Two Bipolar Poet',
#  'Love Phlows Between Phish and Phan',
#  'Cyrano, My Love',
#  'Young Love Caught in the Grips of 9/1',
#  "An Offer of Love He Can't Refus",
#  'Intertwining Love and Obsessio',
#  'Quincy’ Captures a Lifelong Love Affair With Musi',
#  "Mother's Message on Love and Deat",
#  'Sex and the City, From Hong Kong to Beijin',
#  'Wife of a Spy',
#  'When Mother Love Fails, The Community Steps I',
#  'The Mountain Between Us',
#  'Hope Gap',
#  'How to Train Your Dragon: The Hidden World',
#  'A Timeless Tale of True Love in Digital Vide',
#  'They Be Foolish Mortals Who Love the Nightlif',
#  'May-December Love Can Lead to Disconten',
#  'Finding Love On the Road Not Take',
#  'Cassandro',
#  'My Love Affair With Marriage',
#  "HOW 'SMASH PALACE' PLUMBS THE RUINS OF LOV",
#  "They Meet, They Love, He's a Boor, She's Di",
#  'Review/Film; Love Recaptured, Far From the Alaskan Tundr',
#  'Love Blooms Amid the Gri',
#  'Minimum-Wage Slackers in Lov',
#  'True Love and a Crisis at Christmas (When Else)',
#  'To What Great Lengths True Love Will Trave',
#  'FOOL FOR LOV',
#  'The Road to True Love Is Paved With a Whole Lot of Lyin',
#  "How's Love in the 90's? In a Word, Depressin",
#  'Review/Film Festival; Roundelay Of Love On an Isle In Wartim',
#  'Monday',
#  'My Policeman',
#  "It's Never Too Late to Fall In Love, the Tango Show",
#  "A 50's Picket Fence Around Lov",
#  "Review/Film;   'Vital Signs,' On Doctors In Love And Conflic",
#  "Critic's Choice/Film; Mayhem and Young Love In a Chilling Prototyp",
#  'Paris 05:59 Théo & Hugo’ Finds Two Men Out to Get Luck',
#  'Ariana Grande: Excuse Me, I Love You',
#  'A Love Triangle Where Rage Is a Proble',
#  'Love, Sex, Desire and Lyrics (Oh, and Stiletto Pumps) Across the Decade',
#  'Love Among the Gas Pump',
#  'Love in a Mixed Marriage Is Framed by a Lot of Hat',
#  'An Oft-Told Love Fable, Layer by Exotic Laye',
#  'A Paragon of Honor, With a Little Time Off for Lov',
#  "Where Hearts Don't Cheat, And Love Is the Curren",
#  'Thelma,’ a Woman in Love Can Burn Down the Worl',
#  'Theft, Adultery and Good Old Lov',
#  'Family Values and Love In Vietnam Aftermat',
#  'Almost Holy’ Demonstrates a Pastor’s Tough Love for Street Kids in Ukrain']

# %% [markdown]
# ### Access The Movie Database API

# %% [markdown]
# CE Note - Pasted part of the Challenge documentation:
#
# Part 2: Access The Movie Database API
# Consult the Search & Query [https://developer.themoviedb.org/docs/search-and-query-for-details] for Details documentationLinks to an external site. to build your query URLs. You will be making both types of requests to extract all of the details you need:
#
# The search query is used to find the movie ID from the search by title. Most of this query is included in your starter code, as follows, but you will need to include the movie title in the query.
#
# The movie query is made once you have the movie ID.
#
# You will use the titles list created in Part 1 to perform your queries with The Movie Database.

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "api_key=" + tmdb_api_key

#CE Note: tested the queries required in the next cell with one movie below to make all 
#the components would work for the loop.


# movie = "Sublime"

movie_url = "https://api.themoviedb.org/3/movie/"

#search_query = url + movie + "&" + tmdb_key_string

# tmdb_json = requests.get(search_query).json()

#print(json.dumps(tmdb_json, indent = 5))

# movie_key = tmdb_json["results"][0]["id"]

# movie_query = movie_url + str(movie_key) + "?" + tmdb_key_string

# movie_details_json = requests.get(movie_query).json()

#print(json.dumps(movie_details_json, indent = 5))

# print(titles)

#CE NOTE: testing genre.languages, countries list for next cell's instructions.
# print(movie_details_json["genres"])
genres = movie_details_json["genres"]
languages = movie_details_json["spoken_languages"]
countries = movie_details_json["production_countries"]

# genres_list = [g["name"] for g in genres if "name" in g]
# print(genres_list)

# #CE NOTE: testing spoken_languages for the next step.
# spoken_languages = [s["name"] for s in languages if "name" in s]
# print(spoken_languages)


# #CE NOTE: testing production_countries for the next step.
# production_countries = [p["name"] for p in countries if "name" in p]
# print(production_countries)

## CE NOTE: testing dictionary addition for next step.


movie_data = ["title", "original_title", "budget", "original_language", "homepage", "overview", "popularity", "runtime", "revenue", "release_date", "vote_average", "vote_count"]

# for movie in movie_data:
#     movie_data_dict[str(movie)] = movie_details_json[movie]

# movie_data_dict["genres"] = genres_list
# movie_data_dict["spoken_languages"] = spoken_languages
# movie_data_dict["production_countries"] = production_countries
    
# print(movie_data_dict)

#CE NOTE: printed the title to see the info I should expect.
for title in titles:
    print(title)
# Out:
# Sublime
# Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr
# Short-Order Cookery And Dreams of Lov
# Review/Film; It's Harry  [ Loves ]  Sally in a Romance Of New Yorkers and Neurose
# Love’s Eternal Masquerad
# The Tomorrow Man
# FILM REVIEW;Equal Opportunity in Games of Lov
# Marriage Story
# Bones and All
# Love, Antosha
# You Can Live Forever
# From Tapestried Villa to Sylvan Glade, Aristocratic Women in Lov
# A Love Triangle Like No Other in 'Two Drifters'
# Teenager Dies, Leaving Love, and a Life, Behin
# FILM REVIEW;Of a Circus, Church and Lesbian Lov
# Homage to a Poet Who Loved Polan
# Review/Film;   Love and Pain Among the Gentry in Irelan
# Prem Ratan Dhan Payo,’ a Bollywood Tale of a Prince-and-Plebe Doubl
# Review/Film; Mysticism and Love Inside a Hammer and Sickl
# A Promoter Finds a New Cause: Go
# Now They’ll Love Me, a Twin Sister Scheme
# On the Streets of Lisbon, Love, Romance and Desir
# They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil
# The Trivially Hip: A Music Geek's Warped Love Lif
# A Journal for Jordan
# Sexism and Rothbart As Obstacles to Lov
# Another Version of Star-Crossed Lov
# A United Kingdom’ With Love That Tested Racial Toleranc
# A Father and a Son Tell Their Own Tales of Love and Los
# Who’s Afraid of an Artist Who Loved Flowers
# Proof That Science Can’t Find You Lov
# Serenading Love and Life, 30 Years Afte
# For the Love of Money And the Risks of Making I
# Joseph Loves Sarah and So Does Frank, and Everybody Is Talking About I
# Love in Transitio
# Sophie and the Rising Sun’ Has Forbidden Love in a Foreboding Tim
# Their Love Will Go On In Outer Spac
# A Young Viagra Salesman Sees Lust Turn Into Lov
# Loved One
# 50 Years and 600 Women Later, True Lov
# 'ELENI' ENSHRINES ON FILM A MOTHER'S LEGACY OF LOV
# Italians in Lov
# Books of The Times; Wastepaper Love Story Amid the Cellar's Secret
# Reviews/Film; Of Butchers and Lov
# Review/Film; Love Is Blind And Memory Is Bluffe
# Love and Unhappiness, in Soft Shades of Gra
# Lost in Paris
# Lost and Love’ (‘Shi Gu’) Stars Andy Lau as a Man Searching for His Lost So
# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1



# Loop through the titles
for title in titles:
   
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0:
        time.sleep(1)
      
    # Add 1 to the request counter
    request_counter += 1
    
    search_query = url + str(title) + "&" + tmdb_key_string
    
    # Perform a "GET" request for The Movie Database
    tmdb_json = requests.get(search_query).json()

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        movie = str(title)
        # Get movie id
        movie_key = tmdb_json["results"][0]["id"]
        
        # Make a request for a the full movie details
        movie_query = movie_url + str(movie_key) + "?" + tmdb_key_string

        # Execute "GET" request with url
        movie_details_json = requests.get(movie_query).json()
        
        # Extract the genre names into a list
        genres_list = [g["name"] for g in genres if "name" in g]

        # Extract the spoken_languages' English name into a list
        spoken_languages = [s["name"] for s in languages if "name" in s]

        # Extract the production_countries' name into a list
        production_countries = [p["name"] for p in countries if "name" in p]

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        
        """Create a dictionary with the following results: title, original_title, budget, original_language, homepage, overview, popularity, runtime, revenue, release_date, vote_average, vote_count, as well as the genres, spoken_languages, and production_countries lists you just created.
        
        Append this dictionary to tmdb_movies_list."""
        movie_data_dict = {}
        
        for data in movie_data:
            movie_data_dict[str(data)] = movie_details_json[data]

        movie_data_dict["genres"] = genres_list
        movie_data_dict["spoken_languages"] = spoken_languages
        movie_data_dict["production_countries"] = production_countries
        
        tmdb_movies_list.append(movie_data_dict)
        
        # Print out the title that was found
        print(f"{movie_details_json['title']} was found and appended.")
        
        """Print out the name of the movie and a message to indicate that the title was found. 
        Use the except clause to print out a statement if a movie is not found."""
        
    except:
        print(f"{title} was not found.")
# Out:
# Sublime was found and appended.
# Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr was not found.
# Short-Order Cookery And Dreams of Lov was not found.
# Review/Film; It's Harry  [ Loves ]  Sally in a Romance Of New Yorkers and Neurose was not found.
# Love’s Eternal Masquerad was not found.
# The Tomorrow Man was found and appended.
# FILM REVIEW;Equal Opportunity in Games of Lov was not found.
# Marriage Story was found and appended.
# Bones and All was found and appended.
# Love, Antosha was found and appended.
# You Can Live Forever was found and appended.
# From Tapestried Villa to Sylvan Glade, Aristocratic Women in Lov was not found.
# A Love Triangle Like No Other in 'Two Drifters' was not found.
# Teenager Dies, Leaving Love, and a Life, Behin was not found.
# FILM REVIEW;Of a Circus, Church and Lesbian Lov was not found.
# Homage to a Poet Who Loved Polan was not found.
# Review/Film;   Love and Pain Among the Gentry in Irelan was not found.
# Prem Ratan Dhan Payo,’ a Bollywood Tale of a Prince-and-Plebe Doubl was not found.
# Review/Film; Mysticism and Love Inside a Hammer and Sickl was not found.
# A Promoter Finds a New Cause: Go was not found.
# Now They’ll Love Me, a Twin Sister Scheme was not found.
# On the Streets of Lisbon, Love, Romance and Desir was not found.
# They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil was not found.
# The Trivially Hip: A Music Geek's Warped Love Lif was not found.
# A Journal for Jordan was found and appended.
# Sexism and Rothbart As Obstacles to Lov was not found.
# Another Version of Star-Crossed Lov was not found.
# A United Kingdom’ With Love That Tested Racial Toleranc was not found.
# A Father and a Son Tell Their Own Tales of Love and Los was not found.
# Who’s Afraid of an Artist Who Loved Flowers was not found.
# Proof That Science Can’t Find You Lov was not found.
# How to Train Your Dragon: The Hidden World was found and appended.
# A Timeless Tale of True Love in Digital Vide was not found.
# They Be Foolish Mortals Who Love the Nightlif was not found.
# May-December Love Can Lead to Disconten was not found.
# Finding Love On the Road Not Take was not found.
# Cassandro was found and appended.
# My Love Affair with Marriage was found and appended.
# HOW 'SMASH PALACE' PLUMBS THE RUINS OF LOV was not found.
# They Meet, They Love, He's a Boor, She's Di was not found.
# Review/Film; Love Recaptured, Far From the Alaskan Tundr was not found.
# Love Blooms Amid the Gri was not found.
# Minimum-Wage Slackers in Lov was not found.
# True Love and a Crisis at Christmas (When Else) was not found.
# To What Great Lengths True Love Will Trave was not found.
# Fool for Love was found and appended.
# The Road to True Love Is Paved With a Whole Lot of Lyin was not found.
# How's Love in the 90's? In a Word, Depressin was not found.
# Review/Film Festival; Roundelay Of Love On an Isle In Wartim was not found.
# Monday was found and appended.
# My Policeman was found and appended.
# It's Never Too Late to Fall In Love, the Tango Show was not found.
# A 50's Picket Fence Around Lov was not found.
# Review/Film;   'Vital Signs,' On Doctors In Love And Conflic was not found.
# Critic's Choice/Film; Mayhem and Young Love In a Chilling Prototyp was not found.
# Paris 05:59 / Théo & Hugo was found and appended.
# ariana grande: excuse me, i love you was found and appended.
# A Love Triangle Where Rage Is a Proble was not found.
# Love, Sex, Desire and Lyrics (Oh, and Stiletto Pumps) Across the Decade was not found.
# Love Among the Gas Pump was not found.
# Love in a Mixed Marriage Is Framed by a Lot of Hat was not found.
# An Oft-Told Love Fable, Layer by Exotic Laye was not found.
# A Paragon of Honor, With a Little Time Off for Lov was not found.
# Where Hearts Don't Cheat, And Love Is the Curren was not found.
# Thelma,’ a Woman in Love Can Burn Down the Worl was not found.
# Theft, Adultery and Good Old Lov was not found.
# Family Values and Love In Vietnam Aftermat was not found.
# Almost Holy’ Demonstrates a Pastor’s Tough Love for Street Kids in Ukrain was not found.

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data

# CE NOTE: sliced the list to get the first 5 results only.
print(json.dumps(tmdb_movies_list[:5], indent = 4))
# Out:
# [
#     {
#         "title": "Sublime",
#         "original_title": "Sublime",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "",
#         "overview": "Admitted to Mt. Abaddon Hospital for a routine procedure, George Grieves discovers that his condition is much more serious and complicated than originally expected; and as his own fears begin to manifest around him, he learns that Mt. Abaddon is not a place where people come to get better... it is a place where people come to die.",
#         "popularity": 7.733,
#         "runtime": 113,
#         "revenue": 0,
#         "release_date": "2007-06-15",
#         "vote_average": 5.257,
#         "vote_count": 109,
#         "genres": [
#             "Horror",
#             "Thriller"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "The Tomorrow Man",
#         "original_title": "The Tomorrow Man",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://bleeckerstreetmedia.com/thetomorrowman",
#         "overview": "Ed Hemsler spends his life preparing for a disaster that may never come. Ronnie Meisner spends her life shopping for things she may never use. In a small town somewhere in America, these two people will try to find love while trying not to get lost in each other\u2019s stuff.",
#         "popularity": 7.427,
#         "runtime": 94,
#         "revenue": 0,
#         "release_date": "2019-05-22",
#         "vote_average": 5.639,
#         "vote_count": 54,
#         "genres": [
#             "Horror",
#             "Thriller"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Marriage Story",
#         "original_title": "Marriage Story",
#         "budget": 18000000,
#         "original_language": "en",
#         "homepage": "https://www.marriagestorymovie.com",
#         "overview": "A stage director and an actress struggle through a grueling, coast-to-coast divorce that pushes them to their personal extremes.",
#         "popularity": 21.789,
#         "runtime": 137,
#         "revenue": 2300000,
#         "release_date": "2019-09-28",
#         "vote_average": 7.746,
#         "vote_count": 6607,
#         "genres": [
#             "Horror",
#             "Thriller"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Bones and All",
#         "original_title": "Bones and All",
#         "budget": 18000000,
#         "original_language": "it",
#         "homepage": "https://www.bonesandallfilm.net/",
#         "overview": "Abandoned by her father, a young woman embarks on a thousand-mile odyssey through the backroads of America where she meets a disenfranchised drifter. But despite their best efforts, all roads lead back to their terrifying pasts and to a final stand that will determine whether their love can survive their otherness.",
#         "popularity": 23.093,
#         "runtime": 131,
#         "revenue": 15100000,
#         "release_date": "2022-11-18",
#         "vote_average": 7.086,
#         "vote_count": 1127,
#         "genres": [
#             "Horror",
#             "Thriller"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Love, Antosha",
#         "original_title": "Love, Antosha",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://antonyelchindoc.com/",
#         "overview": "From a prolific career in film and television, Anton Yelchin left an indelible legacy as an actor. Through his journals and other writings, his photography, the original music he wrote, and interviews with his family, friends, and colleagues, this film looks not just at Anton's impressive career, but at a broader portrait of the man.",
#         "popularity": 6.771,
#         "runtime": 92,
#         "revenue": 0,
#         "release_date": "2019-08-02",
#         "vote_average": 7.255,
#         "vote_count": 49,
#         "genres": [
#             "Horror",
#             "Thriller"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     }
# ]

# %% [markdown]
# CE Note - Pasted part of the Challenge documentation: Convert the results to a DataFrame called tmdb_df with pd.DataFrame(). You don't need to use json_normalize() this time because we don't have nested objects.

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)
tmdb_df
# Out:
#                                          title  \
# 0                                      Sublime
# 1                             The Tomorrow Man
# 2                               Marriage Story
# 3                                Bones and All
# 4                                Love, Antosha
# 5                         You Can Live Forever
# 6                         A Journal for Jordan
# 7       DeRosa: Life, Love & Art in Transition
# 8                 To Me, the One Who Loved You
# 9                        Love, the Italian Way
# 10                               Lost in Paris
# 11                               Fallen Leaves
# 12                                         Foe
# 13                          Sweet Sex and Love
# 14                         Hard Luck Love Song
# 15                                See You Then
# 16                     Red, White & Royal Blue
# 17                                      Kalank
# 18                   Your Name Engraved Herein
# 19                               Love for Sale
# 20                                  I Miss You
# 21                                    Together
# 22                          Before, Now & Then
# 23                                    Alcarràs
# 24                             Queen of Hearts
# 25                            Falling Inn Love
# 26                      The Sun Is Also a Star
# 27                                 The Creator
# 28                        For Da Love of Money
# 29                                Book of Love
# 30                   My Psychedelic Love Story
# 31             How to Talk to Girls at Parties
# 32                       All the Bright Places
# 33                             Cyrano, My Love
# 34                               Wife of a Spy
# 35                     The Mountain Between Us
# 36                                    Hope Gap
# 37  How to Train Your Dragon: The Hidden World
# 38                                   Cassandro
# 39                My Love Affair with Marriage
# 40                               Fool for Love
# 41                                      Monday
# 42                                My Policeman
# 43                   Paris 05:59 / Théo & Hugo
# 44        ariana grande: excuse me, i love you
#
#                                 original_title     budget original_language  \
# 0                                      Sublime          0                en
# 1                             The Tomorrow Man          0                en
# 2                               Marriage Story   18000000                en
# 3                                Bones and All   18000000                it
# 4                                Love, Antosha          0                en
# 5                         You Can Live Forever          0                en
# 6                         A Journal for Jordan   25000000                en
#
#                                              overview  popularity  runtime  \
# 0   Admitted to Mt. Abaddon Hospital for a routine...       7.733      113
# 1   Ed Hemsler spends his life preparing for a dis...       7.427       94
# 2   A stage director and an actress struggle throu...      21.789      137
# 3   Abandoned by her father, a young woman embarks...      23.093      131
# 4   From a prolific career in film and television,...       6.771       92
# 5   When Jaime, a gay teenager, is sent to live in...       4.879       96
# 6   Based on the true story of First Sergeant Char...      10.841      131
# 7   Chronicles the extraordinary life of artist Fe...       0.600       66
# 8   Koyomi Hidaka and Shiori Sato meet at his fath...      29.154       98
# 9   A group of passengers traveling around the Med...       2.214      100
# 10  Fiona visits Paris for the first time to assis...       8.242       83
# 11  The story of two lonely people who meet each o...      67.173       81
# 12  Henrietta and Junior farm a secluded piece of ...      96.690      111
# 13  Dong-Ki has one night stand with Shin-Ah, a wo...      40.124       85
# 14  Jesse, a charismatic but down on his luck trou...       2.803      104
# 15  A decade after abruptly breaking up with Naomi...       0.840       74
# 16  After an altercation between Alex, the preside...      56.616      121
# 17  Set in 1945, in Pre-Independent India, the eli...       8.957      166
# 18  In 1987, as martial law ends in Taiwan, Jia-ha...      15.608      114
# 19  In northern Brazil, Hermila patiently waits fo...       3.083       90
# 20  Following his son Gabriel’s death, Jorge trave...       3.532      105
# 21  A husband and wife are forced to re-evaluate t...      10.637       87
# 22  Set against Indonesia’s turbulent post-indepen...       2.458      103
# 23  In a small village in Catalonia, the peach far...      15.095      120
# 24  Anne, a brilliant and dedicated advocacy lawye...      32.858      127
# 25  When a San Francisco exec wins a New Zealand i...      12.907       98
# 26  Two young New Yorkers begin to fall in love ov...      10.607      100
# 27  Amid a future war between the human race and t...     213.381      134
# 28  When rumors start circling that average guy Dr...       1.201       97
# 29  Henry, an English writer who has written a new...      11.824      106
# 30  An examination of the notorious high priest of...       1.773      107
# 31  In 1970s London, a teenage outsider named Enn ...      11.853      103
# 32  Two teens facing personal struggles form a pow...      24.354      108
# 33  Paris, France, December 1897. The young playwr...       9.710      113
# 34  It’s 1940, and the population of Japan is divi...       9.513      114
# 35  Stranded on a mountain after a tragic plane cr...      22.984      109
# 36  Grace lives an idyllic life in a British seasi...      11.393      100
# 37  As Hiccup fulfills his dream of creating a pea...      86.276      104
# 38  The true story of Saúl Armendáriz, a gay amate...       9.941      107
# 39  From an early age, songs and fairytales convin...       3.587      108
# 40  A woman is waiting in a motel for her boyfrien...       7.417      106
# 41  A spark on a Friday can lead to a sizzling wee...      10.002      116
# 42  In the late 1990s, the arrival of elderly inva...      11.515      113
# 43  Théo and Hugo meet in a club and form an immed...       8.833       97
# 44  Ariana Grande takes the stage in London for he...       9.050       97
#
#       revenue release_date  vote_average  vote_count              genres  \
# 0           0   2007-06-15         5.257         109  [Horror, Thriller]
# 1           0   2019-05-22         5.639          54  [Horror, Thriller]
# 2     2300000   2019-09-28         7.746        6607  [Horror, Thriller]
# 3    15100000   2022-11-18         7.086        1127  [Horror, Thriller]
# 4           0   2019-08-02         7.255          49  [Horror, Thriller]
# 20        [English]  [United States of America]
# 21        [English]  [United States of America]
# 22        [English]  [United States of America]
# 23        [English]  [United States of America]
# 24        [English]  [United States of America]
# 25        [English]  [United States of America]
# 26        [English]  [United States of America]
# 27        [English]  [United States of America]
# 28        [English]  [United States of America]
# 29        [English]  [United States of America]
# 30        [English]  [United States of America]
# 31        [English]  [United States of America]
# 32        [English]  [United States of America]
# 33        [English]  [United States of America]
# 34        [English]  [United States of America]
# 35        [English]  [United States of America]
# 36        [English]  [United States of America]
# 37        [English]  [United States of America]
# 38        [English]  [United States of America]
# 39        [English]  [United States of America]
# 40        [English]  [United States of America]
# 41        [English]  [United States of America]
# 42        [English]  [United States of America]
# 43        [English]  [United States of America]
# 44        [English]  [United States of America]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
nyt_tmdb = pd.merge(tmdb_df, reviews_df, on = "title")
nyt_tmdb.columns
# Out:
# Index(['title', 'original_title', 'budget', 'original_language', 'homepage',
#        'overview', 'popularity', 'runtime', 'revenue', 'release_date',
#        'vote_average', 'vote_count', 'genres', 'spoken_languages',
#        'production_countries', 'web_url', 'snippet', 'source', 'keywords',
#        'pub_date', 'word_count', 'headline.main', 'headline.kicker',
#        'headline.content_kicker', 'headline.print_headline', 'headline.name',
#        'headline.seo', 'headline.sub', 'byline.original', 'byline.person',
#        'byline.organization'],
#       dtype='object')

# %%
"""The genres, spoken_languages, and production_countries columns were saved as lists, but we want the columns to be 
strings without the list characters ([, ], and '). To fix these columns, perform the following actions:

Create a list of the columns that need fixing called columns_to_fix.

Create a list of characters to remove called characters_to_remove.

Loop through columns_to_fix and do the following:

Use astype() to convert the column to a string.

Loop through the characters_to_remove and use the Pandas str.replace() method to remove the character from the string.

Print the head of the updated DataFrame to confirm the list characters were removed.

Delete any duplicate rows and reset the index.

Export data to a CSV file without the DataFrame's index."""
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["genres", "spoken_languages", "production_countries"]

# Create a list of characters to remove
characters_to_remove = ['\u005B', '\u005D','\u0027']

# Loop through the list of columns to fix
for col in columns_to_fix:

    # Convert the column to type 'str'
    nyt_tmdb[col] = nyt_tmdb[col].astype(str)

    # Loop through characters to remove
    for char in characters_to_remove:
        nyt_tmdb[col] = nyt_tmdb[col].str.replace(char,"")

# Display the fixed DataFrame
# CE NOTE: used an iloc to display the columns where the change took place.
nyt_tmdb.iloc[:,12:18].head()
# Out:
#              genres spoken_languages      production_countries  \
# 0  Horror, Thriller          English  United States of America
# 1  Horror, Thriller          English  United States of America
# 2  Horror, Thriller          English  United States of America
# 3  Horror, Thriller          English  United States of America
# 4  Horror, Thriller          English  United States of America
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/06/20/movies/subl...
# 1  https://www.nytimes.com/2019/05/21/movies/the-...
# 2  https://www.nytimes.com/2019/11/05/movies/marr...
# 3  https://www.nytimes.com/2022/11/17/movies/bone...
# 4  https://www.nytimes.com/2019/08/08/movies/love...
#
#                                              snippet              source
# 0  A teenager dreams of pop songs, and his best f...  The New York Times
# 1  Blythe Danner and John Lithgow strain to eleva...  The New York Times
# 2  Adam Driver and Scarlett Johansson self-consci...  The New York Times
# 3  Luca Guadagnino’s latest stars Timothée Chalam...  The New York Times
# 4  Anton Yelchin, who played Chekov in the J.J. A...  The New York Times

# %%
# Drop "byline.person" column
nyt_tmdb = nyt_tmdb.drop(columns = ["byline.person"], axis = 1)
nyt_tmdb.columns
# Out:
# Index(['title', 'original_title', 'budget', 'original_language', 'homepage',
#        'overview', 'popularity', 'runtime', 'revenue', 'release_date',
#        'vote_average', 'vote_count', 'genres', 'spoken_languages',
#        'production_countries', 'web_url', 'snippet', 'source', 'keywords',
#        'pub_date', 'word_count', 'headline.main', 'headline.kicker',
#        'headline.content_kicker', 'headline.print_headline', 'headline.name',
#        'headline.seo', 'headline.sub', 'byline.original',
#        'byline.organization'],
#       dtype='object')

# %%
# Delete duplicate rows and reset index
#CE Note: printed before and after info details
print(nyt_tmdb.info())
nyt_tmdb_df = nyt_tmdb.drop_duplicates()
nyt_tmdb_df = nyt_tmdb_df.reset_index(drop=True)
nyt_tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    33 non-null     object
#  1   original_title           33 non-null     object
#  2   budget                   33 non-null     int64
#  3   original_language        33 non-null     object
#  4   homepage                 33 non-null     object
#  5   overview                 33 non-null     object
#  6   popularity               33 non-null     float64
#  7   runtime                  33 non-null     int64
#  8   revenue                  33 non-null     int64
#  9   release_date             33 non-null     object
#  10  vote_average             33 non-null     float64
#  11  vote_count               33 non-null     int64
#  12  genres                   33 non-null     object
#  13  spoken_languages         33 non-null     object
#  14  production_countries     33 non-null     object
#  15  web_url                  33 non-null     object
#  16  snippet                  33 non-null     object
#  17  source                   33 non-null     object
#  18  keywords                 33 non-null     object
#  19  pub_date                 33 non-null     object
#  20  word_count               33 non-null     int64
#  21  headline.main            33 non-null     object
#  22  headline.kicker          7 non-null      object
#  23  headline.content_kicker  0 non-null      object
#  24  headline.print_headline  33 non-null     object
#  25  headline.name            0 non-null      object
#  26  headline.seo             0 non-null      object
#  27  headline.sub             0 non-null      object
#  28  byline.original          33 non-null     object
#  29  byline.organization      0 non-null      object
# dtypes: float64(2), int64(5), object(23)
# memory usage: 7.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    33 non-null     object
#  1   original_title           33 non-null     object
#  2   budget                   33 non-null     int64
#  3   original_language        33 non-null     object
#  4   homepage                 33 non-null     object
#  5   overview                 33 non-null     object
#  6   popularity               33 non-null     float64
#  7   runtime                  33 non-null     int64
#  8   revenue                  33 non-null     int64
#  9   release_date             33 non-null     object
#  10  vote_average             33 non-null     float64
#  11  vote_count               33 non-null     int64
#  12  genres                   33 non-null     object
#  13  spoken_languages         33 non-null     object
#  14  production_countries     33 non-null     object
#  15  web_url                  33 non-null     object
#  16  snippet                  33 non-null     object
#  17  source                   33 non-null     object
#  18  keywords                 33 non-null     object
#  19  pub_date                 33 non-null     object
#  20  word_count               33 non-null     int64
#  21  headline.main            33 non-null     object
#  22  headline.kicker          7 non-null      object
#  23  headline.content_kicker  0 non-null      object
#  24  headline.print_headline  33 non-null     object
#  25  headline.name            0 non-null      object
#  26  headline.seo             0 non-null      object
#  27  headline.sub             0 non-null      object
#  28  byline.original          33 non-null     object
#  29  byline.organization      0 non-null      object
# dtypes: float64(2), int64(5), object(23)
# memory usage: 7.9+ KB

# %%
# Export data to CSV without the index
nyt_tmdb_df.to_csv("movie_data_output.csv", index=False)
